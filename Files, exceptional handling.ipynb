# %%
# Theory Questions

# %%
# Q1.
# Ans. Interpreted Languages:- Code is executed line by line by an interpreter.
# the interpreter translates the source code directly into actions.
# A compiler translates the entire program into machine code
# which can then be run by the system's hardware.

# %%
# Q 2
# ans. Exception handling in Python is a mechanism to manage and respond to runtime errors.
#Ensuring that your programs can gracefully handle unexpected situations without crashing.

# %%
# Q 3. The finally block in exception handling serves to execute a set of statements regardless of whether an exception was raised or not.

# %%
# Q 4.
# ans.Logging in Python is a way to track events that happen when some software runs.
#It's a means to record information about a program's execution, which can be extremely useful for debugging, monitoring, and tracking the flow of a program.

# %%
# Q 5.
# ans.The __del__ method in Python is a special method known as a destructor.
#It is called when an object is about to be destroyed, allowing you to define clean-up actions that should be taken when an object’s life cycle comes to an end.

# %%
#Q6.
#ans.In Python, both import and from ... import are used to include external modules or specific parts of them into your program

# %%
# Q7.
# Multiple except blocks: Handle each exception type separately.

#Single except block with multiple exceptions: Handle multiple exceptions together.

#Generic except block: Catch all exceptions (use with caution).

#else block: Execute code if no exceptions are raised.

#finally block: Always execute cleanup code.

# %%
# Q 8.
#ans.The with statement in Python is used to handle files efficiently and safely by ensuring that resources are properly managed.
#It simplifies file handling and provides a cleaner, more readable syntax.

# %%
# Q 9.
# ans. Multithreading and multiprocessing are both techniques used to achieve parallelism in computing.
# But they work in fundamentally different ways and are suited for different types of tasks.

# %%
# Q 10.
# Ans.Using logging in a program offers several significant advantages that contribute to the robustness, maintainability, and reliability of the software.

# %%
# Q 11.
# ans.Memory management in Python involves the efficient allocation and deallocation of memory to ensure that applications run smoothly without unnecessary memory consumption or leaks.

# %%
# Q 12.
# ans.Exception handling in Python involves a sequence of steps that help manage and respond to runtime errors gracefully.

# %%
# Q 13.
# ans. Memory management in Python is crucial for several reasons, contributing to the overall performance, efficiency, and reliability of applications.

# %%
# Q 14.
# ans.The try and except statements in Python are fundamental constructs used for exception handling, allowing you to manage runtime errors gracefully.

# %%
#Q 15.
# Ans. Python's garbage collection (GC) system is responsible for automatically managing memory by identifying and freeing up memory that is no longer in use.
# It helps ensure efficient memory utilization and prevents memory leaks.

# %%
#Q 16
#ans. The else block in exception handling is used to specify a block of code that should run if no exceptions are raised in the try block. It's a way to separate the normal execution path from the error handling code, providing better readability and organization.

# %%
# Q 17.
# ans.In Python, the logging module provides several logging levels to categorize the severity or importance of log messages. Each level is associated with a numeric value, and these levels help filter and manage log output.

# %%
#Q 18.
# ans. os.fork() and the multiprocessing module in Python are both used to create new processes, but they have some fundamental differences in their approach and use cases.

# %%
#Q 19.
# ans.

# %%
# Q 20
# ans. In Python, file.read() and file.readline() are methods used to read the contents of a file, but they operate in different ways and serve different purposes:

# %%
# Q 21.
# ans. The logging module in Python is used to track events that happen when some software runs.
# It provides a flexible framework for emitting log messages from Python programs.
# These log messages can be directed to various outputs, such as the console, files, or remote servers.

# %%
# Q 22.
# ans.The os module in Python provides a way of using operating system-dependent functionality like reading or writing to the file system.
# It includes a number of methods for interacting with the operating system, particularly for file handling and directory management.

# %%
# Q 23.
# Ans.Memory management in Python, while largely automated, does come with its own set of challenges. Here are some of the key challenges associated with memory management in Python:

# %%
# Q 24
# ans .In Python, you can manually raise an exception using the raise statement.
# This is useful when you want to signal that an error has occurred or enforce specific conditions in your code.

# %%
# Q 25.
# ans. Multithreading is important in certain applications for several reasons, as it can significantly enhance performance, responsiveness, and efficiency.

# %%
                                           # practical questions

# %%
# Q 1.

with open('example.txt', 'w') as file:

    file.write('Hello, World!')

# %%
# Q 2 .

# Open the file in read mode
with open('example.txt', 'r') as file:

    for line in file:
        print(line, end='')
# Out:
# Hello, World!

# %%
# Q 3 .

try:
    with open('nonexistent_file.txt', 'r') as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print("Error: The file does not exist.")
# Out:
# Error: The file does not exist.

# %%
# Q 4 .

def copy_file_content(source_file_path, destination_file_path):
    try:
        # Open the source file in read mode
        with open(source_file_path, 'r') as source_file:
            content = source_file.read()

        # Open the destination file in write mode
        with open(destination_file_path, 'w') as destination_file:
            destination_file.write(content)

        print("Content successfully copied from source to destination file.")
    except FileNotFoundError:
        print(f"Error: The file '{source_file_path}' does not exist.")
    except IOError as e:
        print(f"Error: An I/O error occurred. Details: {e}")

# Example usage
source_file_path = 'source.txt'
destination_file_path = 'destination.txt'
copy_file_content(source_file_path, destination_file_path)
# Out:
# Error: The file 'source.txt' does not exist.

# %%
# Q 5

def divide(a, b):
    try:
        result = a / b
    except ZeroDivisionError:
        print("Error: Division by zero is not allowed.")
        return None
    else:
        return result

numerator = 10
denominator = 0
result = divide(numerator, denominator)
if result is not None:
    print(f"The result is {result}")
# Out:
# Error: Division by zero is not allowed.

# %%
# Q 6

import logging

# Configure the logging system
logging.basicConfig(filename='error_log.txt', level=logging.ERROR, format='%(asctime)s - %(levelname)s - %(message)s')

def divide(a, b):
    try:
        result = a / b
        return result
    except ZeroDivisionError as e:
        logging.error("Division by zero error occurred", exc_info=True)
        print("Error: Division by zero is not allowed.")
        return None

numerator = 10
denominator = 0
result = divide(numerator, denominator)
if result is not None:
    print(f"The result is {result}")
# Out:
# ERROR:root:Division by zero error occurred
# Traceback (most recent call last):
#   File "<ipython-input-11-07c672f55516>", line 10, in divide
#     result = a / b
#              ~~^~~
# ZeroDivisionError: division by zero
# Error: Division by zero is not allowed.

# %%
# Q 7

import logging

# Configure the logging system
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# Log messages at different levels
logging.debug('This is a debug message')
logging.info('This is an informational message')
logging.warning('This is a warning message')
logging.error('This is an error message')
logging.critical('This is a critical message')
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %%
# Q 8


def read_file(file_path):
    try:
        # Attempt to open the file in read mode
        with open(file_path, 'r') as file:
            content = file.read()
            print("File content:")
            print(content)
    except FileNotFoundError:
        print("Error: The file does not exist.")
    except IOError as e:
        print(f"Error: An I/O error occurred. Details: {e}")

# Example usage
file_path = 'nonexistent_file.txt'
read_file(file_path)
# Out:
# Error: The file does not exist.

# %%
# Q 9
# ANS.

# Function to read file content line by line and store it in a list
def read_file_to_list(file_path):
    content_list = []
    try:
        with open(file_path, 'r') as file:
            for line in file:
                content_list.append(line.strip())  # Strip newline characters and add to the list
        return content_list
    except FileNotFoundError:
        print("Error: The file does not exist.")
        return []
    except IOError as e:
        print(f"Error: An I/O error occurred. Details: {e}")
        return []

# Example usage
file_path = 'example.txt'
lines = read_file_to_list(file_path)
print(lines)
# Out:
# ['Hello, World!']

# %%
# Q 10

# Function to append data to an existing file
def append_to_file(file_path, data):
    try:
        # Open the file in append mode
        with open(file_path, 'a') as file:
            # Write the data to the file
            file.write(data + '\n')  # Adding a newline character for each entry
        print("Data appended successfully.")
    except IOError as e:
        print(f"Error: An I/O error occurred. Details: {e}")

# Example usage
file_path = 'example.txt'
data_to_append = 'This is the new data to be appended.'
append_to_file(file_path, data_to_append)
# Out:
# Data appended successfully.

# %%
#Q 11

# Function to get a value from a dictionary by key
def get_value_from_dict(dictionary, key):
    try:
        # Attempt to access the dictionary key
        value = dictionary[key]
        return value
    except KeyError:
        # Handle the case where the key doesn't exist
        print(f"Error: The key '{key}' does not exist in the dictionary.")
        return None

# Example usage
my_dict = {'name': 'Ram', 'age': 30, 'city': 'delhi'}
key_to_access = 'country'

value = get_value_from_dict(my_dict, key_to_access)
if value is not None:
    print(f"The value for the key '{key_to_access}' is {value}")
# Out:
# Error: The key 'country' does not exist in the dictionary.

# %%
# Q 12

# Function to demonstrate multiple exception handling
def exception_demo(a, b, index):
    try:
        # Division operation
        result = a / b
        print(f"Result of division: {result}")

        # Accessing a list element
        my_list = [1, 2, 3]
        element = my_list[index]
        print(f"Element at index {index}: {element}")

    except ZeroDivisionError:
        print("Error: Division by zero is not allowed.")

    except IndexError:
        print(f"Error: Index {index} is out of range.")

    except TypeError:
        print("Error: Invalid input type.")

# Example usage
exception_demo(10, 0, 1)
exception_demo(10, 2, 5)
exception_demo('10', 2, 1)
# Out:
# Error: Division by zero is not allowed.
# Result of division: 5.0
# Error: Index 5 is out of range.
# Error: Invalid input type.

# %%
# Q 13

import os

file_path = "path/to/your/file.txt"

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
        # Process the file content
        print(content)
else:
    print(f"Error: File '{file_path}' not found.")
# Out:
# Error: File 'path/to/your/file.txt' not found.

# %%
# Q 14

import logging

# Configure the logger
logging.basicConfig(level=logging.DEBUG,
                    format='%(asctime)s - %(levelname)s - %(message)s')

# Log an informational message
logging.info('Program started')

def divide(x, y):
    try:
        result = x / y
    except ZeroDivisionError:
        # Log an error message
        logging.error('Division by zero!')
        return None
    else:
        return result

# Perform a division that will be logged as info
result1 = divide(10, 2)
logging.info(f'Result of 10 / 2: {result1}')


# Perform a division that will be logged as error
result2 = divide(10, 0)
logging.info(f'Result of 10 / 0: {result2}')


# Log another informational message
logging.info('Program finished')
# Out:
# INFO:root:Program started
# INFO:root:Result of 10 / 2: 5.0
# ERROR:root:Division by zero!
# INFO:root:Result of 10 / 0: None
# INFO:root:Program finished

# %%
# Q 15

def print_file_content(file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            if content:
                print("File content:")
                print(content)
            else:
                print("The file is empty.")
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' does not exist.")
    except IOError as e:
        print(f"Error: An I/O error occurred. Details: {e}")

# Example usage
file_path = 'example.txt'
print_file_content(file_path)
# Out:
# File content:
# Hello, World!This is the new data to be appended.

# %%
# Q 16

pip install memory_profiler
# Out:
#   File "<ipython-input-24-f91dcacb9894>", line 3
#     pip install memory_profiler
#         ^
# SyntaxError: invalid syntax

# %%
# Q 17

def write_numbers_to_file(file_path, numbers):
    try:
        with open(file_path, 'w') as file:
            for number in numbers:
                file.write(f"{number}\n")
        print("Numbers successfully written to the file.")
    except IOError as e:
        print(f"Error: An I/O error occurred. Details: {e}")

# Example usage
file_path = 'numbers.txt'
numbers = list(range(1, 101))  # Create a list of numbers from 1 to 100
write_numbers_to_file(file_path, numbers)
# Out:
# Numbers successfully written to the file.

# %%
# Q 18

import logging
from logging.handlers import RotatingFileHandler

# Configure the logging system
log_file = 'app_log.txt'
max_log_size = 1 * 1024 * 1024  # 1MB
backup_count = 3  # Number of backup files to keep

# Create a rotating file handler
handler = RotatingFileHandler(log_file, maxBytes=max_log_size, backupCount=backup_count)

# Set the logging format
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

# Get the root logger and configure it
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)  # Set the logging level to DEBUG to capture all levels of messages
logger.addHandler(handler)

# Example log messages
logger.debug('This is a debug message')
logger.info('This is an informational message')
logger.warning('This is a warning message')
logger.error('This is an error message')
logger.critical('This is a critical message')

print("Logging setup with rotation is complete. Check the log file for messages.")
# Out:
# DEBUG:root:This is a debug message
# INFO:root:This is an informational message
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message
# Logging setup with rotation is complete. Check the log file for messages.

# %%
# Q 19

def handle_exceptions():
    # Example list and dictionary
    my_list = [10, 20, 30]
    my_dict = {'a': 1, 'b': 2}

    try:
        # Attempt to access an index that may cause an IndexError
        print(f"List element: {my_list[3]}")  # This will cause an IndexError

        # Attempt to access a dictionary key that may cause a KeyError
        print(f"Dictionary value: {my_dict['c']}")  # This will cause a KeyError

    except IndexError as e:
        print(f"IndexError: {e}")

    except KeyError as e:
        print(f"KeyError: {e}")

    # Additional code to run regardless of exceptions
    print("Exception handling completed.")

# Example usage
handle_exceptions()
# Out:
# IndexError: list index out of range
# Exception handling completed.

# %%
# 20

def read_file(file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            return content
    except FileNotFoundError:
        return f"Error: The file '{file_path}' does not exist."
    except IOError as e:
        return f"Error: An I/O error occurred. Details: {e}"

# Example usage
file_path = 'example.txt'
file_content = read_file(file_path)
print(file_content)
# Out:
# Hello, World!This is the new data to be appended.

# %%
# Q21

def count_word_occurrences(file_path, target_word):
    try:
        with open(file_path, 'r') as file:
            content = file.read()

        # Convert the content to lowercase and split into words
        words = content.lower().split()

        # Count the occurrences of the target word
        word_count = words.count(target_word.lower())

        print(f"The word '{target_word}' occurs {word_count} times in the file.")
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' does not exist.")
    except IOError as e:
        print(f"Error: An I/O error occurred. Details: {e}")

# Example usage
file_path = 'example.txt'
target_word = 'specific'
count_word_occurrences(file_path, target_word)
# Out:
# The word 'specific' occurs 0 times in the file.

# %%
# Q22

import os

def is_file_empty(file_path):
    try:
        if os.path.getsize(file_path) == 0:
            print("The file is empty.")
        else:
            with open(file_path, 'r') as file:
                content = file.read()
                print("File content:")
                print(content)
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' does not exist.")
    except IOError as e:
        print(f"Error: An I/O error occurred. Details: {e}")

# Example usage
file_path = 'example.txt'
is_file_empty(file_path)
# Out:
# File content:
# Hello, World!This is the new data to be appended.

# %%
# Q 23

import logging

# Configure the logging system
logging.basicConfig(filename='file_error_log.txt', level=logging.ERROR, format='%(asctime)s - %(levelname)s - %(message)s')

def read_file(file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            return content
    except FileNotFoundError:
        logging.error(f"FileNotFoundError: The file '{file_path}' does not exist.")
        return None
    except IOError as e:
        logging.error(f"IOError: An I/O error occurred while accessing the file '{file_path}'. Details: {e}")
        return None

def write_file(file_path, data):
    try:
        with open(file_path, 'w') as file:
            file.write(data)
            print("Data successfully written to the file.")
    except IOError as e:
        logging.error(f"IOError: An I/O error occurred while writing to the file '{file_path}'. Details: {e}")

# Example usage
read_file_path = 'nonexistent_file.txt'
write_file_path = 'example.txt'
data_to_write = "Hello, World!"

# Attempt to read a file (which does not exist) to trigger an error
content = read_file(read_file_path)

# Attempt to write to a file
write_file(write_file_path, data_to_write)
# Out:
# ERROR:root:FileNotFoundError: The file 'nonexistent_file.txt' does not exist.
# Data successfully written to the file.
